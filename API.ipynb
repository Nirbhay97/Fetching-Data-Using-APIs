# %%
import pandas as pd
import requests

# %%
res = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=14a1fb6b10a7914322e4830605833b45&language=en-US&page=4')

# %%
res
# Out:
# <Response [200]>

# %%
df = pd.DataFrame(res.json()['results'])

# %%
df
# Out:
#     adult                     backdrop_path          genre_ids      id  \
# 0   False  /oJmBWLUCKbgra8D9ZrLE1nBic5v.jpg    [35, 18, 10749]      13
# 1   False  /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg        [10749, 35]  761053
# 2   False  /sw7mordbZxgITU877yTpZCud90M.jpg           [18, 80]     769
# 3   False  /zoVeIgKzGJzpdG6Gwnr7iOYfIMU.jpg        [18, 10749]   11216
# 4   False  /qvZ91FwMq6O47VViAr8vZNQz3WI.jpg           [28, 18]     346
# 5   False  /6aNKD81RHR1DqUUa8kOZ1TBY1Lp.jpg           [35, 18]     637
# 6   False  /uPYa165sraN2c8gZBM9C47g3JoU.jpg           [18, 80]     311
# 7   False  /gwj4R8Uy1GwejKqfofREKI9Jh7L.jpg    [16, 18, 10752]   12477
# 8   False  /uif5fUshJrXyyDzfpzp1DLw3N0S.jpg       [27, 18, 53]     539
# 9   False  /nC3IjYhUgZWgfKfFX0ygMigFwgc.jpg       [28, 18, 36]   14537
# 10  False  /xs6awEGjnH3e36YSAromfYu3PBQ.jpg       [35, 18, 14]   40096
# 11  False  /rr7E0NoGKxvbkb89eR1GwfoYjpA.jpg               [18]     550
# ...

# %%
ntdf = pd.DataFrame(res.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]

# %%
df.head()
# Out:
#    adult                     backdrop_path           genre_ids     id  \
# 0  False  /s3TBrRGB1iav7gFOCNx3H31MoES.jpg       [28, 878, 12]  27205
# 1  False  /ps82zgSDimvlYps6otcMYshrVyS.jpg     [35, 18, 10749]    901
# 2  False  /hkKTtlHjiVUW5XRfkQfl3FmJUfX.jpg      [80, 9648, 53]    807
# 3  False  /2xliq3zIrQPIWG66Fc0bgVoBUWc.jpg  [80, 18, 9648, 53]  12493
# 4  False  /mpNd0rTVrp6vHJ9Je7wSa3zC8JS.jpg        [12, 14, 16]    128
#
#   original_language original_title  \
# 0                en      Inception
# 1                en    City Lights
# 2                en          Se7en
# 3                ja          天国と地獄
# 4                ja          もののけ姫
#
#                                             overview  popularity  \
# 0  Cobb, a skilled thief who commits corporate es...     122.887
# 1  In this sound-era silent film, a tramp falls i...      12.481
# 2  Two homicide detectives are on a desperate hun...      66.337
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 3):
    res = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=14a1fb6b10a7914322e4830605833b45&language=en-US&page={}'.format(i))
    tempdf =  pd.DataFrame(res.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
    df = df.append(tempdf, ignore_index = True)

# %%
df
# Out:
#            id                              title  \
# 0         238                      The Godfather
# 1         278           The Shawshank Redemption
# 2         240              The Godfather Part II
# 3       19404        Dilwale Dulhania Le Jayenge
# 4         424                   Schindler's List
# ...       ...                                ...
# 10035     598                        City of God
# 10036  324857  Spider-Man: Into the Spider-Verse
# 10037  255709                               Hope
# 10038  652837      Josee, the Tiger and the Fish
# 10039  378064          A Silent Voice: The Movie
#
#                                                 overview release_date  \
# 0      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1      Framed in the 1940s for the double murder of h...   1994-09-23
# 2      In the continuing saga of the Corleone crime f...   1974-12-20
# 3      Raj is a rich, carefree, happy-go-lucky second...   1995-10-19
# ...

# %%
df.sort_values('vote_count', ascending = False)
# Out:
#            id              title  \
# 60      27205          Inception
# 53     157336       Interstellar
# 14        155    The Dark Knight
# 10014     155    The Dark Knight
# 810     24428       The Avengers
# ...       ...                ...
# 6033    14195  Cecil B. Demented
# 7798   309581         Lila & Eve
# 1021   592807            Papicha
# 2031    59037         Toxic Love
# 5048    42691        Oedipus Rex
#
#                                                 overview release_date  \
# 60     Cobb, a skilled thief who commits corporate es...   2010-07-15
# 53     The adventures of a group of explorers who mak...   2014-11-05
# 14     Batman raises the stakes in his war on crime. ...   2008-07-14
# 10014  Batman raises the stakes in his war on crime. ...   2008-07-14
# 810    When an unexpected enemy emerges and threatens...   2012-04-25
# ...                                                  ...          ...
# ...

# %%
df.shape
# Out:
# (10040, 7)

# %%
t = pd.DataFrame()
t
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 50):
    res = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=14a1fb6b10a7914322e4830605833b45&language=en-US&page={}'.format(i))
    temp__df =  pd.DataFrame(res.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
    t = t.append(temp__df, ignore_index = True)

# %%
t
# Out:
#          id                           title  \
# 0       238                   The Godfather
# 1       278        The Shawshank Redemption
# 2       240           The Godfather Part II
# 3     19404     Dilwale Dulhania Le Jayenge
# 4       424                Schindler's List
# ..      ...                             ...
# 975  180299                      The Raid 2
# 976   10322                     Being There
# 977  283995  Guardians of the Galaxy Vol. 2
# 978    8429                          Paisan
# 979    1726                        Iron Man
#
#                                               overview release_date  \
# 0    Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1    Framed in the 1940s for the double murder of h...   1994-09-23
# 2    In the continuing saga of the Corleone crime f...   1974-12-20
# 3    Raj is a rich, carefree, happy-go-lucky second...   1995-10-19
# 4    The true story of how businessman Oskar Schind...   1993-12-15
# ...

# %%
19*49
# Out:
# 931

# %%
19*547
# Out:
# 10393

# %%
df
# Out:
#            id                              title  \
# 0         238                      The Godfather
# 1         278           The Shawshank Redemption
# 2         240              The Godfather Part II
# 3       19404        Dilwale Dulhania Le Jayenge
# 4         424                   Schindler's List
# ...       ...                                ...
# 10035     598                        City of God
# 10036  324857  Spider-Man: Into the Spider-Verse
# 10037  255709                               Hope
# 10038  652837      Josee, the Tiger and the Fish
# 10039  378064          A Silent Voice: The Movie
#
#                                                 overview release_date  \
# 0      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1      Framed in the 1940s for the double murder of h...   1994-09-23
# 2      In the continuing saga of the Corleone crime f...   1974-12-20
# 3      Raj is a rich, carefree, happy-go-lucky second...   1995-10-19
# ...
